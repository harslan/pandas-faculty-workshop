# %% [markdown]
# # 🎯 Hands-On Practice: Business Data Analysis
# ## Your Turn to Explore Data!
#
# **Time:** 15 minutes
# **Objective:** Apply Pandas skills to real business data
#
# ---
#
# ## 📋 The Scenario:
#
# You're analyzing a real business dataset. Your mission is to extract meaningful insights that could inform strategic decisions.
#
# **Your Mission:** Answer key research questions using Pandas
#
# ---

# %% [markdown]
# ## 📝 Instructions:
#
# **Don't panic!** 😊
#
# - Each exercise has **hints** - use them if stuck
# - Multiple approaches are valid
# - Focus on insights, not perfect code
# - Ask questions in chat!
#
# **Grading:** There are no grades! This is about learning. 🎓
#
# ---

# %% [markdown]
# ## Step 0: Setup (Run This First!)
#
# **Action:** Run this cell to import libraries and load the dataset

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization defaults
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

print('✅ Setup complete!')
print(f'📊 Dataset loaded: {df.shape[0]} rows × {df.shape[1]} columns')
print('\nFor this practice, think of this as business/customer data')
print('Now start with Exercise 1 below!')

# %% [markdown]
# ---
# # 📝 Exercise 1: Initial Data Exploration (3 minutes)
#
# **Goal:** Understand what data you're working with

# %% [markdown]
# ## Question 1.1: Display the first 10 rows
#
# **Hint:** Use `.head()` with a parameter

# %%
# Your code here:

# %% [markdown]
# ## Question 1.2: What are the column names?
#
# **Hint:** Use `.columns`

# %%
# Your code here:

# %% [markdown]
# ## Question 1.3: Get summary statistics
#
# **Task:** Display statistical summary for all numerical columns
# **Hint:** Use `.describe()`

# %%
# Your code here:

# %% [markdown]
# ## Question 1.4: Check for missing data
#
# **Task:** How many missing values are in each column?
# **Hint:** Use `.isnull().sum()`

# %%
# Your code here:

# %% [markdown]
# ---
# # 📊 Exercise 2: Answering Research Questions (5 minutes)
#
# **Goal:** Extract meaningful insights from the data

# %% [markdown]
# ## Question 2.1: Overall survival rate
#
# **Task:** What percentage of passengers survived?
# **Hint:** Calculate the mean of the 'Survived' column and multiply by 100

# %%
# Your code here:

# %% [markdown]
# ## Question 2.2: Average fare by class
#
# **Task:** What's the average fare for each passenger class?
# **Hint:** Use `.groupby('Pclass')['Fare'].mean()`

# %%
# Your code here:

# %% [markdown]
# ## Question 2.3: Gender analysis
#
# **Task:** Compare survival rates between male and female passengers
# **Hint:** Use `.groupby('Sex')['Survived'].mean()`

# %%
# Your code here:

# %% [markdown]
# ## Question 2.4: Age distribution
#
# **Task:** What's the age range of passengers? (min, max, mean)
# **Hint:** Use `.min()`, `.max()`, `.mean()` on the Age column

# %%
# Your code here:

# %% [markdown]
# ---
# # 🔍 Exercise 3: Data Filtering (4 minutes)
#
# **Goal:** Segment data for targeted analysis

# %% [markdown]
# ## Question 3.1: High fare passengers
#
# **Task:** Filter for passengers who paid more than $100
# **Hint:** Use `df[df['Fare'] > 100]`

# %%
# Your code here:
high_fare = # your filtering code

# Display results
print(f'Number of high-fare passengers: {len(high_fare)}')
print(f'Average fare: ${high_fare["Fare"].mean():.2f}')

# %% [markdown]
# ## Question 3.2: Young survivors
#
# **Task:** Filter for passengers under 30 who survived
# **Hint:** Use multiple conditions with & operator: `(df['Age'] < 30) & (df['Survived'] == 1)`

# %%
# Your code here:
young_survivors = # your filtering code

# Display results
print(f'Young survivors: {len(young_survivors)}')
print(f'Average age: {young_survivors["Age"].mean():.1f} years')

# %% [markdown]
# ## Question 3.3: Class comparison
#
# **Task:** Compare first-class vs third-class passengers
# **Challenge:** Calculate average fare and survival rate for both

# %%
# Your code here:
first_class = # filter for Pclass == 1
third_class = # filter for Pclass == 3

# Display comparison
print('First Class:')
print(f'  Average Fare: ${first_class["Fare"].mean():.2f}')
print(f'  Survival Rate: {first_class["Survived"].mean()*100:.1f}%')
print('\nThird Class:')
print(f'  Average Fare: ${third_class["Fare"].mean():.2f}')
print(f'  Survival Rate: {third_class["Survived"].mean()*100:.1f}%')

# %% [markdown]
# ---
# # 📊 Exercise 4: Create Visualizations (3 minutes)
#
# **Goal:** Tell the data story visually

# %% [markdown]
# ## Question 4.1: Fare distribution
#
# **Task:** Create a histogram of fares
# **Hint:** Use `df['Fare'].plot(kind='hist')`

# %%
# Your code here:
# Create histogram

plt.title('Fare Distribution')
plt.xlabel('Fare ($)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Question 4.2: Survival by class
#
# **Task:** Create a bar plot showing survival rate by passenger class
# **Hint:** Use Seaborn: `sns.barplot(data=df, x='Pclass', y='Survived')`

# %%
# Your code here:
plt.figure(figsize=(10, 6))
# Create bar plot

plt.title('Survival Rate by Class', fontsize=14, fontweight='bold')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# ## Question 4.3: Fare by gender (BONUS!)
#
# **Task:** Create a box plot comparing fares by gender
# **Hint:** Use `sns.boxplot(data=df, x='Sex', y='Fare')`

# %%
# Your code here (optional):

# %% [markdown]
# ---
# # 🎯 Reflection Questions
#
# **Think about:**
#
# 1. What was the most surprising finding?
# 2. What additional analysis would you want to do?
# 3. How could you use Pandas in YOUR research?
#
# **Share in chat!** 💬
#
# ---
#
# # 🎉 You're Done!
#
# Great work! You've applied Pandas to real business questions.
#
# **Next:** We'll review solutions together
#
# **Remember:** There's no single 'right' way - focus on insights! 🚀
